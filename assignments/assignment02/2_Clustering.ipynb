# %% [markdown]
# # Exploring Chemical Space
# Explore some clustering and visualisation models and compare them for two different datasets:
# - A subset of ChEMBL small molecule entries with a molecular weight between 200 and 500. Since the entire set of ChEMBL entries is quite substantial, 10k entries were selected by random sampling (`chembl_200-500_10k`)
# - The result of the PubChem search for "antibiotics" (`pubchem_antibiotics`).
#
# Note: The ChEMBL dataset may still take quite some processing time - depending on your PC. You can do a random sampling of e.g. 3k entries in order to reduce the computational effort.
#
# Tasks:
# 1) Load and inspect the two datasets `ChEMBL_200-500_10k.csv`. Note that they are fundamentally different.
# 2) Perform basic data cleaning and be mindful of which data to dismiss (if any). Hint: Think about standardising column names (at least for the relevant ones)
# 3) Make sure that the SMILES strings are valid - implement a function to clean up the SMILES returning (in a new column or Series) the canonical SMILES if the input is valid, and return `None` if the SMILES in the original data is not valid (). Hint: The `Normalizer` in  rdkit might be quite useful (https://www.rdkit.org/docs/cppapi/classRDKit_1_1MolStandardize_1_1Normalizer.html)
# 4) Calculate Morgan Fingerprints (radius 2, 2048 bit) from the SMILES strings via mol objects. Make sure not to use the outdated version. You can use either the dataframe, numpy arrays or simple lists for the fingerprints.
# 5) Run different clustering techniques, e.g. snippets provided for Butina and HDBSCAN. You can also try the scikit-learn models kmeans or dbscan.
# 6) Use the fingerprints to run UMAP and TSNE dimensionality reductions (snippets provided).
# 7) Plot the data in scatterplots, using the cluster labels as colour map.
# 8) Adjust some parameters of the clustering models and apply filters if needed (e.g. only visualise clusters of a size larger than 10) to reach some satisfactory result
# 9) Visualise a representative molecule (e.g. centroids or centers of clusters, or random :) ) of the three largest clusters for both methods using rdkit
# 10) Respond to the discussion points

# %% [markdown]
# Import dependencies and datasets

# %%
# complete imports if needed for your solution
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from rdkit import Chem
from rdkit.Chem.MolStandardize.rdMolStandardize import Normalizer
from rdkit.Chem import rdFingerprintGenerator
from rdkit import DataStructs
from rdkit.ML.Cluster import Butina
from rdkit.Chem import Draw

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
import hdbscan
import umap
from sklearn.manifold import TSNE

# %%
df_chem = pd.read_csv("chembl_200-500_10k.csv")
df_anti = pd.read_csv("pubchem_antibiotics.csv")

# %%
df_chem.head(5)
# Out:
#        ChEMBL ID Name Synonyms            Type  Max Phase  Molecular Weight  \
# 0    CHEMBL50524  NaN      NaN  Small molecule        NaN            361.47
# 1  CHEMBL1719619  NaN      NaN  Small molecule        NaN            339.35
# 2  CHEMBL1989505  NaN      NaN  Small molecule        NaN            417.54
# 3  CHEMBL1673052  NaN      NaN  Small molecule        NaN            487.61
# 4  CHEMBL3084770  NaN      NaN  Small molecule        NaN            426.56
#
#    Targets  Bioactivities  AlogP  Polar Surface Area  ...  Heavy Atoms  \
# 0      2.0            2.0   1.96               84.66  ...         25.0
# 1      4.0            4.0   2.33              110.62  ...         25.0
# 2      2.0            2.0   6.02               92.93  ...         30.0
# 3      3.0            9.0   4.12               77.07  ...         36.0
# 4      1.0            1.0   3.58               70.84  ...         31.0
#
#    Np Likeness Score  Molecular Formula  \
# 0              -0.79        C18H23N3O3S
# 1              -0.90         C18H17N3O4
# 2              -1.12         C23H23N5OS
# 3              -1.28         C27H33N7O2
# 4              -0.62         C24H34N4O3
#
#                                               SMILES  \
# 0         Nc1c(NC/C=C\COc2csc(CN3CCCCC3)c2)c(=O)c1=O
# 1      COc1ccc(OC)c(C2C(C#N)=C(N)Oc3cc(C)nc(O)c32)c1
# 2  Cc1ccc(NC(=O)Nc2ccc(-c3c(C(C)C)sc4ncnc(N)c34)c...
# 3  COc1cc(N2CCN(C)CC2)ccc1Nc1ncc2c(n1)N(C(C)C)c1c...
# 4  CC[C@H]1COC[C@H](C)N1c1nc2c(C(=O)N[C@@H]3C[C@H...
#
#                      Inchi Key  \
# 0  ZXLCEKMBIFPOSF-DJWKRKHSSA-N
# 1  ATRZEYKVGNFNIL-UHFFFAOYSA-N
# 2  OCRAIYGHHHMVJB-UHFFFAOYSA-N
# 3  YYTFTZONXCQXLW-UHFFFAOYSA-N
# 4  UIKMHGOYAXJLIA-VPAKFMSCSA-N
#
#                                                Inchi  Withdrawn Flag Orphan  \
# 0  InChI=1S/C18H23N3O3S/c19-15-16(18(23)17(15)22)...           False     -1
# 1  InChI=1S/C18H17N3O4/c1-9-6-14-16(18(22)21-9)15...           False     -1
# 2  InChI=1S/C23H23N5OS/c1-13(2)20-18(19-21(24)25-...           False     -1
# 3  InChI=1S/C27H33N7O2/c1-18(2)34-22-9-7-6-8-20(2...           False     -1
# 4  InChI=1S/C24H34N4O3/c1-4-17-14-30-13-15(2)28(1...           False     -1
#
#                          Records Key  \
# 0                            ['12a']
# 1       ['SID859991', 'SID87345386']
# 2                   ['SID103904394']
# 3  ['24', 'XMD10-78', 'Compound 18']
# 4                             ['35']
#
#                                         Records Name
# 0  ['3-Amino-4-[(Z)-4-(5-piperidin-1-ylmethyl-thi...
# 1                       ['SID859991', 'SID87345386']
# 2                                   ['SID103904394']
# 3  ['11-isopropyl-2-((2-methoxy-4-(4-methylpipera...
# 4  ['endo-2-((3S,5S)-3-ethyl-5-methylmorpholino)-...
#
# [5 rows x 29 columns]

# %%
df_anti.head(5)
# Out:
#    Compound_CID                 Name  \
# 0      16131155   Antibiotic A 47934
# 1       6439108  Antibiotic S 632-B1
# 2       9690107    Antibiotic FK 089
# 3        125607    Antibiotic A447 C
# 4       5487319    DOB-41 antibiotic
#
#                                             Synonyms Molecular_Formula  \
# 0  A-47934 Antibiotic|Antibiotic A 47934|RefChem:...   C58H44Cl3N7O21S
# 1  Antibiotic S 632-B1|121995-32-2|S632-B1|S632-B...         C17H25NO5
# 2  FK-089 antibiotic|Antibiotic FK 089|86070-74-8...      C14H12N4O7S2
# 3  Antibiotic A447 C|95599-38-5|Antibiotic A447-C...       C60H88N2O20
# 4  Dob-41 antibiotic|Antibiotic dob 41|115666-98-...        C19H18N2O6
#
#                                                InChI  \
# 0  InChI=1S/C58H44Cl3N7O21S/c59-31-7-20-1-4-36(31...
# 1  InChI=1S/C17H25NO5/c1-9(4-10(2)17-11(3)23-17)1...
# 2  InChI=1S/C14H12N4O7S2/c19-8(20)3-25-17-9(6-4-2...
# 3  InChI=1S/C60H88N2O20/c1-12-60(70)26-41(79-46-2...
# 4  InChI=1S/C19H18N2O6/c1-10(27-19(25)15(9-22)26-...
#
#                                               Smiles  \
# 0  C1[C@@H]2C(=O)N[C@@H](C3=CC(=CC(=C3)OC4=C(C=CC...
# 1   CC1C(O1)/C(=C\C(C)C(=O)CC(CC2CC(=O)NC(=O)C2)O)/C
# 2  C1C=C(N2[C@H](S1)[C@@H](C2=O)NC(=O)/C(=N\OCC(=...
# 3  CCC1(CC(C2=C(C1OC3CC(C(C(O3)C)OC4CCC(C(O4)C)OC...
# 4  C[C@H](C1=C2C(=CC=C1)N=C3C(=N2)C=CC=C3C(=O)O)O...
#
#                       InChIKey  \
# 0  HRGFAEUWEMDRRZ-QLRHZSCISA-N
# 1  JEIOGENOOQCFDS-WMZJFQQLSA-N
# 2  YVVLVHFJBQEWHH-NSHRYQRRSA-N
# 3  JCVKGZNZMVGUIP-UHFFFAOYSA-N
# 4  OSEDIRANPWGFRX-MEBBXXQBSA-N
#
#                                           IUPAC_Name        MeSH_Headings  \
# 0  (1S,2R,19R,22R,34S,37R,40R,52S)-22-amino-5,15,...   antibiotic A 47934
# 1  4-[(Z)-2-hydroxy-5-methyl-7-(3-methyloxiran-2-...  antibiotic S 632-B1
# 2  (6R,7R)-7-[[(2Z)-2-(carboxymethoxyimino)-2-(1,...    antibiotic FK 089
# 3  7,10-bis[[4-(dimethylamino)-5-[5-(5-hydroxy-6-...    antibiotic A447 C
# 4  6-[(1R)-1-[(2R)-3-hydroxy-2-methoxypropanoyl]o...    DOB-41 antibiotic
#
#                                   Annotation_Content  ...  \
# 0         Classification|Literature|Patents|Taxonomy  ...
# 1                 Classification|Literature|Toxicity  ...
# 2  Biological Test Results|Classification|Literat...  ...
# 3                          Classification|Literature  ...
# 4                  Classification|Literature|Patents  ...
#
#   Defined_Atom_Stereo_Count Undefined_Atom_Stereo_Count  \
# 0                         8                           0
# 1                         0                           4
# 2                         2                           0
# 3                         0                          23
# 4                         2                           0
#
#   Total_Bond_Stereo_Count Defined_Bond_Stereo_Count  \
# 0                       0                         0
# 1                       1                         1
# 2                       1                         1
# 3                       0                         0
# 4                       0                         0
#
#    Undefined_Bond_Stereo_Count  Linked_PubChem_Literature_Count  \
# 0                            0                               17
# 1                            0                                3
# 2                            0                                2
# 3                            0                                1
# 4                            0                                1
#
#    Linked_PubChem_Patent_Count  Linked_PubChem_Patent_Family_Count  \
# 0                           60                                  13
# 1                            0                                   0
# 2                            5                                   1
# 3                            0                                   0
# 4                            5                                   1
#
#    Annotation_Type_Count  Create_Date
# 0                      4     20070703
# 1                      3     20060428
# 2                      4     20061024
# 3                      2     20050808
# 4                      3     20050808
#
# [5 rows x 38 columns]

# %%
df_chem.describe()
# Out:
#        Max Phase  Molecular Weight      Targets  Bioactivities        AlogP  \
# count  75.000000      10000.000000  9593.000000    9593.000000  9946.000000
# mean    2.026667        367.632781     6.980298      10.977692     3.293754
# std     1.314918         71.308667    14.499846      72.107042     1.570448
# min    -1.000000        200.280000     1.000000       1.000000    -5.550000
# 25%     2.000000        315.502500     1.000000       2.000000     2.340000
# 50%     2.000000        368.455000     3.000000       5.000000     3.335000
# 75%     3.000000        423.525000     7.000000      10.000000     4.290000
# max     4.000000        499.700000   613.000000    5992.000000     9.930000
#
#        Polar Surface Area          HBA          HBD  #RO5 Violations  \
# count         9946.000000  9946.000000  9946.000000      9946.000000
# mean            72.823139     4.775990     1.357631         0.134627
# std             30.772358     1.843906     1.153433         0.343983
# min              0.000000     0.000000     0.000000         0.000000
# 25%             51.100000     3.000000     1.000000         0.000000
# 50%             69.910000     5.000000     1.000000         0.000000
# 75%             91.287500     6.000000     2.000000         0.000000
# max            258.840000    16.000000     8.000000         2.000000
#
#        #Rotatable Bonds  QED Weighted  Aromatic Rings  Inorganic Flag  \
# count       9946.000000   9946.000000     9946.000000    10000.000000
# mean           4.922180      0.613163        2.359240       -0.992500
# std            2.604628      0.182504        1.091465        0.086281
# min            0.000000      0.060000        0.000000       -1.000000
# 25%            3.000000      0.480000        2.000000       -1.000000
# 50%            5.000000      0.620000        2.000000       -1.000000
# 75%            6.000000      0.760000        3.000000       -1.000000
# max           23.000000      0.950000        6.000000        0.000000
#
#        Heavy Atoms  Np Likeness Score        Orphan
# count  9946.000000        9946.000000  10000.000000
# mean     25.737181          -0.921939     -0.992400
# std       5.227196           1.015270      0.087994
# min       8.000000          -4.070000     -1.000000
# 25%      22.000000          -1.590000     -1.000000
# 50%      26.000000          -1.080000     -1.000000
# 75%      30.000000          -0.460000     -1.000000
# max      38.000000           4.110000      1.000000

# %%
df_anti.describe()
# Out:
#        Compound_CID  Molecular_Weight   Polar_Area   Complexity        XLogP  \
# count  2.358000e+03       2358.000000  2358.000000  2358.000000  1905.000000
# mean   3.287431e+07        661.647590   227.031293  1169.944444     0.961995
# std    4.844780e+07        396.047313   164.974911   831.344101     3.740470
# min    3.200000e+02         99.090000     3.200000    38.000000   -16.700000
# 25%    1.962080e+05        405.300000   128.000000   647.000000    -1.100000
# 50%    6.450115e+06        544.550000   193.000000   944.000000     1.300000
# 75%    5.468076e+07        814.000000   261.000000  1460.000000     3.400000
# max    1.778574e+08       3545.100000  1690.000000  8160.000000    18.600000
#
#        Heavy_Atom_Count  H-Bond_Donor_Count  H-Bond_Acceptor_Count  \
# count       2358.000000         2358.000000            2358.000000
# mean          45.955047            6.104750              12.417303
# std           27.725970            5.913143               7.577051
# min            7.000000            0.000000               1.000000
# 25%           28.000000            2.000000               7.000000
# 50%           38.000000            4.000000              11.000000
# 75%           58.000000            7.000000              15.000000
# max          243.000000           58.000000              63.000000
#
#        Rotatable_Bond_Count   Exact_Mass  ...  Defined_Atom_Stereo_Count  \
# count           2358.000000  2358.000000  ...                2358.000000
# mean               8.997880   661.124215  ...                   5.918999
# std                8.422624   395.802160  ...                   6.683319
# min                0.000000    99.032028  ...                   0.000000
# 25%                4.000000   404.219879  ...                   0.000000
# 50%                7.000000   543.775238  ...                   3.500000
# 75%               11.000000   813.451050  ...                   9.000000
# max               67.000000  3543.581543  ...                  37.000000
#
#        Undefined_Atom_Stereo_Count  Total_Bond_Stereo_Count  \
# count                  2358.000000              2358.000000
# mean                      2.529686                 0.814673
# std                       5.229701                 1.589103
# min                       0.000000                 0.000000
# 25%                       0.000000                 0.000000
# 50%                       0.000000                 0.000000
# 75%                       2.000000                 1.000000
# max                      33.000000                14.000000
#
#        Defined_Bond_Stereo_Count  Undefined_Bond_Stereo_Count  \
# count                2358.000000                  2358.000000
# mean                    0.715437                     0.099237
# std                     1.487333                     0.602913
# min                     0.000000                     0.000000
# 25%                     0.000000                     0.000000
# 50%                     0.000000                     0.000000
# 75%                     1.000000                     0.000000
# max                    14.000000                    10.000000
#
#        Linked_PubChem_Literature_Count  Linked_PubChem_Patent_Count  \
# count                      2358.000000                  2358.000000
# mean                       1329.260814                  5149.486429
# std                        6876.501858                 15182.253531
# min                           0.000000                     0.000000
# 25%                           1.000000                     1.000000
# 50%                           6.000000                    48.000000
# 75%                         126.750000                  1592.000000
# max                      132224.000000                142293.000000
#
#        Linked_PubChem_Patent_Family_Count  Annotation_Type_Count   Create_Date
# count                         2358.000000            2358.000000  2.358000e+03
# mean                          1420.523325               6.229856  2.008519e+07
# std                           4224.227155               4.539714  5.056542e+04
# min                              0.000000               0.000000  2.004092e+07
# 25%                              1.000000               3.000000  2.005081e+07
# 50%                             18.000000               5.000000  2.006043e+07
# 75%                            482.250000               9.000000  2.011123e+07
# max                          40785.000000              20.000000  2.026013e+07
#
# [8 rows x 25 columns]

# %% [markdown]
# Data cleaning

# %%
#name normalisation

df_chem = df_chem.rename(columns={
    "Molecular Weight" : "Molecular_Weight",
    "Polar Surface Area": "Polar_Area",
    "Heavy Atoms": "Heavy_Atom_Count",
    "#Rotatable Bonds": "Rotatable_Bond_Count",
    "SMILES": "Smiles"
    })
df_chem.head(1)
# Out:
#      ChEMBL ID Name Synonyms            Type  Max Phase  Molecular_Weight  \
# 0  CHEMBL50524  NaN      NaN  Small molecule        NaN            361.47
#
#    Targets  Bioactivities  AlogP  Polar_Area  ...  Heavy_Atom_Count  \
# 0      2.0            2.0   1.96       84.66  ...              25.0
#
#    Np Likeness Score  Molecular Formula  \
# 0              -0.79        C18H23N3O3S
#
#                                        Smiles                    Inchi Key  \
# 0  Nc1c(NC/C=C\COc2csc(CN3CCCCC3)c2)c(=O)c1=O  ZXLCEKMBIFPOSF-DJWKRKHSSA-N
#
#                                                Inchi  Withdrawn Flag Orphan  \
# 0  InChI=1S/C18H23N3O3S/c19-15-16(18(23)17(15)22)...           False     -1
#
#    Records Key                                       Records Name
# 0      ['12a']  ['3-Amino-4-[(Z)-4-(5-piperidin-1-ylmethyl-thi...
#
# [1 rows x 29 columns]

# %%
nan_counts_chem = df_chem.isna().sum()
print(nan_counts_chem[nan_counts_chem > 0].sort_values(ascending=False))
# Out:
# Max Phase               9925
# Synonyms                9918
# Name                    9818
# Targets                  407
# Bioactivities            407
# Records Name             376
# Records Key              376
# AlogP                     54
# Polar_Area                54
# #RO5 Violations           54
# Rotatable_Bond_Count      54
# HBA                       54
# HBD                       54
# QED Weighted              54
# Passes Ro3                54
# Aromatic Rings            54
# Heavy_Atom_Count          54
# Np Likeness Score         54
# Smiles                     7
# Inchi                      7
# Inchi Key                  7
# dtype: int64

# %%
nan_counts_anti = df_anti.isna().sum()
print(nan_counts_anti[nan_counts_anti > 0].sort_values(ascending=False))
# Out:
# Linked_BioAssays      1265
# MeSH_Headings         1234
# Tagged_by_PubChem      925
# XLogP                  453
# Annotation_Content     133
# Synonyms                28
# IUPAC_Name              10
# dtype: int64

# %%
print(df_chem.columns)
print(df_anti.columns)
# Out:
# Index(['ChEMBL ID', 'Name', 'Synonyms', 'Type', 'Max Phase',
#        'Molecular_Weight', 'Targets', 'Bioactivities', 'AlogP', 'Polar_Area',
#        'HBA', 'HBD', '#RO5 Violations', 'Rotatable_Bond_Count', 'Passes Ro3',
#        'QED Weighted', 'Aromatic Rings', 'Structure Type', 'Inorganic Flag',
#        'Heavy_Atom_Count', 'Np Likeness Score', 'Molecular Formula', 'Smiles',
#        'Inchi Key', 'Inchi', 'Withdrawn Flag', 'Orphan', 'Records Key',
#        'Records Name'],
#       dtype='object')
# Index(['Compound_CID', 'Name', 'Synonyms', 'Molecular_Formula', 'InChI',
#        'Smiles', 'InChIKey', 'IUPAC_Name', 'MeSH_Headings',
#        'Annotation_Content', 'Linked_BioAssays', 'Data_Source',
#        'Data_Source_Category', 'Tagged_by_PubChem', 'Molecular_Weight',
#        'Polar_Area', 'Complexity', 'XLogP', 'Heavy_Atom_Count',
#        'H-Bond_Donor_Count', 'H-Bond_Acceptor_Count', 'Rotatable_Bond_Count',
#        'Exact_Mass', 'Monoisotopic_Mass', 'Charge', 'Covalent_Unit_Count',
#        'Isotopic_Atom_Count', 'Total_Atom_Stereo_Count',
#        'Defined_Atom_Stereo_Count', 'Undefined_Atom_Stereo_Count',
#        'Total_Bond_Stereo_Count', 'Defined_Bond_Stereo_Count',
#        'Undefined_Bond_Stereo_Count', 'Linked_PubChem_Literature_Count',
#        'Linked_PubChem_Patent_Count', 'Linked_PubChem_Patent_Family_Count',
#        'Annotation_Type_Count', 'Create_Date'],
#       dtype='object')

# %%
# Polar area, molec weight, rotatable and heavy atom are overlapping cols
chem_cols = list(df_chem.columns)
anti_cols = list(df_anti.columns)

overlapping_cols = []

for i in chem_cols:
    if i in anti_cols:
        overlapping_cols.append(i)

if "Synonyms" in overlapping_cols:
    overlapping_cols.remove("Synonyms")

# remove rows with NaNs in overlapping columns
df_chem = df_chem.dropna(subset=overlapping_cols)
df_anti = df_anti.dropna(subset=overlapping_cols)

# count remaining NaNs
chem_nan_counts = df_chem[overlapping_cols].isna().sum()
anti_nan_counts = df_anti[overlapping_cols].isna().sum()

print("NaNs in df_chem:")
print(chem_nan_counts.sort_values(ascending=False))

print("\nNaNs in df_anti:")
print(anti_nan_counts.sort_values(ascending=False))

#dropped 54 values from chem dataset and ignored synonyms for dropping
# Out:
# NaNs in df_chem:
# Name                    0
# Molecular_Weight        0
# Polar_Area              0
# Rotatable_Bond_Count    0
# Heavy_Atom_Count        0
# Smiles                  0
# dtype: int64
#
# NaNs in df_anti:
# Name                    0
# Molecular_Weight        0
# Polar_Area              0
# Rotatable_Bond_Count    0
# Heavy_Atom_Count        0
# Smiles                  0
# dtype: int64

# %%
print(overlapping_cols)
# Out:
# ['Name', 'Molecular_Weight', 'Polar_Area', 'Rotatable_Bond_Count', 'Heavy_Atom_Count', 'Smiles']

# %%
combined_df = pd.concat([
    df_chem[overlapping_cols],
    df_anti[overlapping_cols]
], ignore_index=True)

# %%
combined_df.head(5)
# Out:
#              Name  Molecular_Weight  Polar_Area  Rotatable_Bond_Count  \
# 0    PUMAFENTRINE            477.65       54.37                   7.0
# 1        CUDC-101            434.50      105.60                  11.0
# 2   LEUCONICINE A            361.45       68.33                   2.0
# 3  MONOSPORASCONE            244.20       76.74                   1.0
# 4   BALAGLITAZONE            395.44       90.29                   5.0
#
#    Heavy_Atom_Count                                             Smiles
# 0              35.0  CCOc1cc2c(cc1OC)C(c1ccc(C(=O)N(C(C)C)C(C)C)cc1...
# 1              32.0   C#Cc1cccc(Nc2ncnc3cc(OC)c(OCCCCCCC(=O)NO)cc23)c1
# 2              27.0  CC[C@@H]1CN2CC[C@]34c5ccccc5-n5c3c(cc(C(N)=O)c...
# 3              18.0                   COc1cc(O)c2c(c1)C(=O)c1cocc1C2=O
# 4              28.0      Cn1c(COc2ccc(CC3SC(=O)NC3=O)cc2)nc2ccccc2c1=O

# %% [markdown]
# Calculate Morgan Fingerprints (`GetMorganGenerator`). You can experiment with other fingerprints (`GetRDKitFPGenerator`) as well and see how they impact the clusters.

# %%
from rdkit.Chem import rdFingerprintGenerator

fp_generator = rdFingerprintGenerator.GetMorganGenerator(radius=2, fpSize=2048)

combined_df["fps"] = combined_df["mol"].apply(
    lambda mol: fp_generator.GetFingerprint(mol) if mol is not None else None
)

fp_list = list(combined_df["fps"])

# %% [markdown]
# Butina Clustering: Investigate later how different cutoffs for the similarity affect the clusters.

# %%
# Butina clustering requires distance matrix (distance = Tanimoto similarity); 
# fingerprints provided as list in this snippet - adjust as needed!


dists = []
nfps = len(fp_list)

for i in range(1, nfps):
    similarities = DataStructs.BulkTanimotoSimilarity(fp_list[i], fp_list[:i])
    dists.extend([1-x for x in similarities])

# Apply Butina Clustering

# Apply different thresholds later and see how they affect the clustering
cutoff = 0.6  # Tanimoto similarity threshold; e.g. 04 for larger chemical families, 0.7 for tight analogues...

butina_clusters = Butina.ClusterData(
    dists, # similarity based distance matrix
    nfps, # number of fingerprints
    cutoff,
    isDistData=True
)

print("Number of clusters:", len(butina_clusters))
# Out:
# Number of clusters: 694

# %%
# filter out small clusters, rare chemoptypes, ...
clusters_filtered = [c for c in butina_clusters if len(c) >= 10]

butina_labels = np.full(nfps, -1)
for cluster_id, cluster in enumerate(clusters_filtered):
    for id in cluster:
        butina_labels[id] = cluster_id

sizes = [len(c) for c in clusters_filtered]

print("clusters:", len(sizes))
print("mean size:", np.mean(sizes))
print("max size:", np.max(sizes))
print("singletons:", sum(s == 1 for s in sizes))
# Out:
# clusters: 49
# mean size: 28.142857142857142
# max size: 125
# singletons: 0

# %% [markdown]
# HDBSCAN Clustering: Inspect how `min_cluster_size` and `min_samples` affect the clusters later on. This might depend quite a lot on the dataset (try 15 and 5 for the PubChem data, <10 and <5 for the ChEMBL)

# %%
# use HDBSCAN for clustering
hdbs_clustering = hdbscan.HDBSCAN(
    min_cluster_size=10,
    min_samples=2,
    metric="euclidean"
)

hdbs_labels = hdbs_clustering.fit_predict(fp_list)
print("Number of DBSCAN clusters:",
       len(set(hdbs_labels)) - (1 if -1 in hdbs_labels else 0))
print("Noise points:", list(hdbs_labels).count(-1))
# Out:
# Number of DBSCAN clusters: 56
# Noise points: 1187

# %%
print("Number of DBSCAN clusters:",
      len(set(hdbs_labels)) - (1 if -1 in hdbs_labels else 0))
print("Noise points:", list(hdbs_labels).count(-1))
# Out:
# Number of DBSCAN clusters: 56
# Noise points: 1187

# %% [markdown]
# Embeddings: TSNE and UMAP

# %%
# convert fingerprints to numpy
X = np.zeros((nfps, 2048), dtype=int)
for i, fp in enumerate(fp_list):
    DataStructs.ConvertToNumpyArray(fp, X[i])

# %%
# Dimensionality reduction by TSNE
umap_model = umap.UMAP(
    n_neighbors=25,
    min_dist=0.2,
    metric="jaccard",
    random_state=42
)

umap_embedding = umap_model.fit_transform(X)
# Out:
# c:\Users\julia\anaconda3\envs\DSA104\Lib\site-packages\umap\umap_.py:1887: UserWarning: gradient function is not yet implemented for jaccard distance metric; inverse_transform will be unavailable
#   warn(
# c:\Users\julia\anaconda3\envs\DSA104\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
# Dimensionality reduction by TSNE
tsne_model = TSNE(
    n_components=3,
    perplexity=30,
    learning_rate="auto",
    init="pca",
    random_state=42
)

tsne_embedding = tsne_model.fit_transform(X)

# %% [markdown]
# Visualise the two clustering methods in the two embeddings (e.g. as subplot). Make sure to label the axes properly.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# UMAP plot
axes[0].scatter(
    umap_embedding[:, 0],
    umap_embedding[:, 1],
    s=10
)
axes[0].set_title("UMAP Projection")

# t-SNE plot
axes[1].scatter(
    tsne_embedding[:, 0],
    tsne_embedding[:, 1],
    s=10
)
axes[1].set_title("t-SNE Projection")

plt.show()

# %% [markdown]
# Visualise representative molecules of the three biggest clusters of both methods.

# %% [markdown]
# ## Discussion points
# 1) What are the characteristics of the chemical spaces described in the two dataset? What is the difference?
# 2) How do density-based clustering techniques compare to models based on similarity in light of the differences in the datasets?
# 3) What were the best model parameters for the clustering techniques (i.e. that delivered a meaningful result)
# 4) Comment on the different dimensionality reduction techniques (again in light of the different dataset characteristics)
# 5) What was the best / most meaningful combination of dimensionality reduction and clustering methods?
# 6) Comment on some cheminformatics modelling challenges you may have encountered (e.g. runtime, singleton clusters, paramtersensitivity). What could be done to work around a large number of clusters of small size?
# 7) On the antibiotics dataset, can you identify some known antibiotic classes / motives in your clusters?

# %% [markdown]
# 1. The ChemBL dataset consists of only small molecules with largely differing structures and functions while the antibiotics one consists of only antibiotic compounds, this will lead to the antibiotic ones having a more similar and more narrow chemical space. While the small molecule one is a lot more broadly distributed with possible overlaps
# 2. Density-based approaches look for spacially close data points and is very dependent on parameters and scaling. Similarity-based ones group data points by fingerprint similarity but requires a pre-defined number of clusters.
# 3. 56 clusters were chosen as the minimum number
# 4. t-SNE only preserves local neighbourhoods but does not care about global relationships which leads to information loss and possible mis-interpretation if distances are "measured". UMAP preserves both local and global structures.
# 5. I would say that a combination of DBSCAN + UMAP would work best as structure is preserved from UMAP and dense clusters are found using DBSCAN which makes more sense for this structural analysis.
# 6. Personally I always struggle most with the data wrangling as I study biomedicine so I always need some time to understand the underlying data and what different things mean and could be meaningful for clustering and analysis.
# 7. Because I combined the data, it is not clear. But it could be made apparent with colouring of the antibiotic morgan fingerprints but I am unsure on how to implement this using a combination of morgan fingerprint and classification as an antibiotic.
